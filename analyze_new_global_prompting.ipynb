# %%
# %load_ext autoreload
# %autoreload 2
# %pip install -r requirements.txt

from constants_and_utils import *

from generate_personas import *
from generate_networks import *
from analyze_networks import *
from plotting import *
from network_datasets import *

import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Collecting matplotlib>=3.8.0 (from -r requirements.txt (line 1))
#   Downloading matplotlib-3.9.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting networkx>=3.1 (from -r requirements.txt (line 2))
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting numpy==1.26.3 (from -r requirements.txt (line 3))
#   Using cached numpy-1.26.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (115 kB)
# Collecting openai>=1.43.1 (from -r requirements.txt (line 4))
#   Downloading openai-1.55.0-py3-none-any.whl.metadata (24 kB)
# Collecting pandas==2.2.0 (from -r requirements.txt (line 5))
#   Using cached pandas-2.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting Pillow>=10.4.0 (from -r requirements.txt (line 6))
#   Downloading pillow-11.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting scikit_learn>=1.5.1 (from -r requirements.txt (line 7))
#   Downloading scikit_learn-1.5.2-cp311-cp311-macosx_12_0_arm64.whl.metadata (13 kB)
# Collecting scipy>=1.14.1 (from -r requirements.txt (line 8))
#   Downloading scipy-1.14.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting seaborn>=0.13.2 (from -r requirements.txt (line 9))
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/wesleyboyer/Library/Python/3.11/lib/python/site-packages (from pandas==2.2.0->-r requirements.txt (line 5)) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas==2.2.0->-r requirements.txt (line 5))
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas==2.2.0->-r requirements.txt (line 5))
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.8.0->-r requirements.txt (line 1))
#   Downloading contourpy-1.3.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.8.0->-r requirements.txt (line 1))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.8.0->-r requirements.txt (line 1))
#   Downloading fonttools-4.55.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (164 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.8.0->-r requirements.txt (line 1))
#   Downloading kiwisolver-1.4.7-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.8.0->-r requirements.txt (line 1)) (24.1)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.8.0->-r requirements.txt (line 1))
#   Using cached pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/homebrew/lib/python3.11/site-packages (from openai>=1.43.1->-r requirements.txt (line 4)) (4.4.0)
# Collecting distro<2,>=1.7.0 (from openai>=1.43.1->-r requirements.txt (line 4))
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/homebrew/lib/python3.11/site-packages (from openai>=1.43.1->-r requirements.txt (line 4)) (0.27.0)
# Collecting jiter<1,>=0.4.0 (from openai>=1.43.1->-r requirements.txt (line 4))
#   Downloading jiter-0.7.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/homebrew/lib/python3.11/site-packages (from openai>=1.43.1->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.11/site-packages (from openai>=1.43.1->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/homebrew/lib/python3.11/site-packages (from openai>=1.43.1->-r requirements.txt (line 4)) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/homebrew/lib/python3.11/site-packages (from openai>=1.43.1->-r requirements.txt (line 4)) (4.12.2)
# Collecting joblib>=1.2.0 (from scikit_learn>=1.5.1->-r requirements.txt (line 7))
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit_learn>=1.5.1->-r requirements.txt (line 7))
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai>=1.43.1->-r requirements.txt (line 4)) (3.7)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai>=1.43.1->-r requirements.txt (line 4)) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai>=1.43.1->-r requirements.txt (line 4)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.43.1->-r requirements.txt (line 4)) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai>=1.43.1->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai>=1.43.1->-r requirements.txt (line 4)) (2.20.1)
# Requirement already satisfied: six>=1.5 in /Users/wesleyboyer/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas==2.2.0->-r requirements.txt (line 5)) (1.16.0)
# Using cached numpy-1.26.3-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
# Using cached pandas-2.2.0-cp311-cp311-macosx_11_0_arm64.whl (11.8 MB)
# Downloading matplotlib-3.9.2-cp311-cp311-macosx_11_0_arm64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 9.2 MB/s eta 0:00:0000:0100:01m
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Downloading openai-1.55.0-py3-none-any.whl (389 kB)
# Downloading pillow-11.0.0-cp311-cp311-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 8.4 MB/s eta 0:00:00ta 0:00:01
# Downloading scikit_learn-1.5.2-cp311-cp311-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 10.6 MB/s eta 0:00:0000:010:01
# Downloading scipy-1.14.1-cp311-cp311-macosx_14_0_arm64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 10.4 MB/s eta 0:00:0000:0100:01
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.1-cp311-cp311-macosx_11_0_arm64.whl (254 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading fonttools-4.55.0-cp311-cp311-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 10.3 MB/s eta 0:00:00a 0:00:01
# Downloading jiter-0.7.1-cp311-cp311-macosx_11_0_arm64.whl (303 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading kiwisolver-1.4.7-cp311-cp311-macosx_11_0_arm64.whl (64 kB)
# Using cached pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, pyparsing, Pillow, numpy, networkx, kiwisolver, joblib, jiter, fonttools, distro, cycler, scipy, pandas, contourpy, scikit_learn, openai, matplotlib, seaborn
# Successfully installed Pillow-11.0.0 contourpy-1.3.1 cycler-0.12.1 distro-1.9.0 fonttools-4.55.0 jiter-0.7.1 joblib-1.4.2 kiwisolver-1.4.7 matplotlib-3.9.2 networkx-3.4.2 numpy-1.26.3 openai-1.55.0 pandas-2.2.0 pyparsing-3.2.0 pytz-2024.2 scikit_learn-1.5.2 scipy-1.14.1 seaborn-0.13.2 threadpoolctl-3.5.0 tzdata-2024.2
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Analyze networks

# %%
network_df = pd.read_csv(f'stats/real/network_metrics.csv')
metric_dfs = [network_df]
homophily_dfs = []

methods = ['global', 'global-expressive', 'local', 'sequential']
methods = ['global', 'global-expressive', 'sequential']
extensions = ['_ALL_SHUFFLED', '_w_interests', '_only_interests', '_temp06', '_temp10', '_prompt_all', '_w_reason']
extensions = ['_w_interests']

# load network metrics and homophily for generated networks
model = 'gpt-4o'
for method in methods:
    for extension in extensions:
        if method != 'global-expressive':
            metric_dfs.append(pd.read_csv(f'stats/{method}_{model}{extension}/network_metrics.csv'))
            homophily_dfs.append(pd.read_csv(f'stats/{method}_{model}{extension}/homophily.csv'))

model = 'gpt-4o'
for method in methods:
    for extension in extensions:
        if method == 'global-expressive':
            metric_dfs.append(pd.read_csv(f'stats/{method}_{model}{extension}_w_reason/network_metrics.csv'))
            homophily_dfs.append(pd.read_csv(f'stats/{method}_{model}{extension}_w_reason/homophily.csv'))
            metric_dfs.append(pd.read_csv(f'stats/{method}_{model}_w_names{extension}_w_reason/network_metrics.csv'))
            homophily_dfs.append(pd.read_csv(f'stats/{method}_{model}_w_names{extension}_w_reason/homophily.csv'))

"""
model = 'llama3.1-8b'
for extension in ['', '_n5']:
    metric_dfs.append(pd.read_csv(f'stats/sequential_{model}{extension}/network_metrics.csv'))
    homophily_dfs.append(pd.read_csv(f'stats/sequential_{model}{extension}/homophily.csv'))

model = 'llama3.1-70b'
for extension in ['', '_n5']:
    metric_dfs.append(pd.read_csv(f'stats/sequential_{model}{extension}/network_metrics.csv'))
    homophily_dfs.append(pd.read_csv(f'stats/sequential_{model}{extension}/homophily.csv'))

model = 'gemma2-9b'
for extension in ['']:
    metric_dfs.append(pd.read_csv(f'stats/sequential_{model}{extension}/network_metrics.csv'))
    homophily_dfs.append(pd.read_csv(f'stats/sequential_{model}{extension}/homophily.csv'))

model = 'gemma2-27b'
for extension in ['', '_n5']:
    metric_dfs.append(pd.read_csv(f'stats/sequential_{model}{extension}/network_metrics.csv'))
    homophily_dfs.append(pd.read_csv(f'stats/sequential_{model}{extension}/homophily.csv'))"""

network_df = pd.concat(metric_dfs)
print(network_df.groupby('save_name').size())

homophily_df = pd.concat(homophily_dfs)
print(homophily_df.groupby('save_name').size())

def rename_network_metrics(n):
    if n == 'prop_nodes_lcc' or n == 'Prop nodes lcc':
        return 'Prop nodes LCC'
    n = n.split('_')
    n = ' '.join(n)
    return n.capitalize()

for n in network_df['metric_name'].unique():
    print(n, rename_network_metrics(n))
    
network_df['metric_name'] = network_df['metric_name'].apply(rename_network_metrics)
network_df.head()

legend_mapper = {'real': 'Real',
                 'global_gpt-4o_w_interests': 'Global (GPT-4o)',
                 'global-expressive_gpt-4o_w_interests': 'global-expressive_gpt-4o_w_interests',
                 'global-expressive_gpt-4o_w_interests_w_reason': 'global-expressive_gpt-4o_w_interests_w_reason',
                 'global-expressive_gpt-4o-mini_w_interests_w_reason': 'global-expressive_gpt-4o-mini_w_interests_w_reason',
                 'global-expressive_gpt-4o_w_names_w_interests_w_reason': 'New Global (GPT-4o)',
                 'sequential_gpt-4o_w_interests': 'Sequential (GPT-4o)'}

# GPT 3.5
x_to_keep = ['Density', 'Avg clustering coef', 'Prop nodes LCC', 'Avg shortest path', 'Modularity', 'Radius', 'Diameter']
network_df[network_df['metric_name'].isin(x_to_keep) & network_df.save_name.str.contains('gpt-3.5')].groupby(['save_name', 'metric_name'])['_metric_value'].agg(['count', 'mean', 'sem']).round(3)

# non-GPT 3.5 
network_df[network_df['metric_name'].isin(x_to_keep) & ~network_df.save_name.str.contains('gpt-3.5')].groupby(['save_name', 'metric_name'])['_metric_value'].agg(['count', 'mean', 'sem']).round(3)

# compare GPT 3.5 vs GPT 4o
to_keep = ['real', 'sequential_gpt-3.5-turbo', 'sequential_gpt-4o', 'sequential_gpt-4o_n5']

to_keep = ['real', 'global_gpt-4o_w_interests', 'global-expressive_gpt-4o_w_names_w_interests_w_reason', 'sequential_gpt-4o_w_interests']
#to_keep = ['real', 'global-expressive_gpt-4o_w_names_w_interests_w_reason', 'sequential_gpt-4o_w_interests']

kept_df = network_df[network_df.save_name.isin(to_keep)]
pastel_palette = sns.color_palette("deep")
colors = {'real': pastel_palette[0],
          'global_gpt-4o_w_interests': pastel_palette[3],
          'global-expressive_gpt-4o_w_interests': pastel_palette[4],
          'global-expressive_gpt-4o_w_interests_w_reason': pastel_palette[5],
          'global-expressive_gpt-4o-mini_w_interests_w_reason': pastel_palette[6],
          'sequential_gpt-4o_w_interests': pastel_palette[7],
          'global-expressive_gpt-4o_w_names_w_interests_w_reason': pastel_palette[8]}

plot_metrics_separately(kept_df, plot_type='default', x_to_keep=x_to_keep, palette=colors, 
                            simplify_legend=True, legend_mapper=legend_mapper)
make_plot(kept_df, plot_type='default', legend_mapper=legend_mapper, palette=colors, x_to_keep=x_to_keep, figsize=(11, 4), legend_pos=(1,1))

to_keep.remove('real')
kept_df = homophily_df[homophily_df.save_name.isin(to_keep)]
make_plot(kept_df, plot_homophily=True, plot_type='default', legend_mapper=legend_mapper, palette=colors, 
          dodge=0.55, figsize=(11, 5), legend_pos=(1,1))

kept_df = homophily_df[homophily_df.save_name.isin(to_keep) & (homophily_df['demo'] != 'age')]
make_plot(kept_df, plot_homophily=True, plot_type='default', legend_mapper=legend_mapper, palette=colors, 
          dodge=0.55, figsize=(11, 5), legend_pos=(1,1))
# Out:
# save_name
# global-expressive_gpt-4o_w_interests_w_reason            4710
# global-expressive_gpt-4o_w_names_w_interests_w_reason    4710
# global_gpt-4o_w_interests                                4710
# real                                                     1097
# sequential_gpt-4o_w_interests                            4710
# dtype: int64
# save_name
# global-expressive_gpt-4o_w_interests_w_reason            300
# global-expressive_gpt-4o_w_names_w_interests_w_reason    300
# global_gpt-4o_w_interests                                300
# sequential_gpt-4o_w_interests                            300
# dtype: int64
# density Density
# avg_clustering_coef Avg clustering coef
# prop_nodes_lcc Prop nodes LCC
# radius Radius
# diameter Diameter
# avg_shortest_path Avg shortest path
# modularity Modularity
# degree_centrality Degree centrality
# betweenness_centrality Betweenness centrality
# closeness_centrality Closeness centrality
# Dropping node-level stats: kept 686 out of 15227 rows
# Keeping rows in ['Density', 'Avg clustering coef', 'Prop nodes LCC', 'Avg shortest path', 'Modularity', 'Radius', 'Diameter']: kept 686 out of 686 rows
# Dropping node-level stats: kept 686 out of 15227 rows
# Keeping rows in ['Density', 'Avg clustering coef', 'Prop nodes LCC', 'Avg shortest path', 'Modularity', 'Radius', 'Diameter']: kept 686 out of 686 rows

# %%
homophily_df = pd.concat(homophily_dfs)
print(homophily_df.groupby('save_name').size())
# Out:
# save_name
# global-expressive_gpt-4o-mini_w_interests_w_reason       300
# global-expressive_gpt-4o_w_interests                     300
# global-expressive_gpt-4o_w_interests_w_reason            300
# global-expressive_gpt-4o_w_names_w_interests_w_reason    200
# global_gpt-4o_w_interests                                300
# sequential_gpt-4o_w_interests                            300
# dtype: int64

# %%
def rename_network_metrics(n):
    if n == 'prop_nodes_lcc' or n == 'Prop nodes lcc':
        return 'Prop nodes LCC'
    n = n.split('_')
    n = ' '.join(n)
    return n.capitalize()

for n in network_df['metric_name'].unique():
    print(n, rename_network_metrics(n))
    
network_df['metric_name'] = network_df['metric_name'].apply(rename_network_metrics)
network_df.head()
# Out:
# density Density
# avg_clustering_coef Avg clustering coef
# prop_nodes_lcc Prop nodes LCC
# radius Radius
# diameter Diameter
# avg_shortest_path Avg shortest path
# modularity Modularity
# degree_centrality Degree centrality
# betweenness_centrality Betweenness centrality
# closeness_centrality Closeness centrality
#    graph_nr          metric_name  _metric_value save_name node
# 0       0.0              Density       0.144444      real  NaN
# 1       0.0  Avg clustering coef       0.415549      real  NaN
# 2       0.0       Prop nodes LCC       0.916667      real  NaN
# 3       0.0               Radius       0.857999      real  NaN
# 4       0.0             Diameter       1.429998      real  NaN

# %%
# GPT 3.5
x_to_keep = ['Density', 'Avg clustering coef', 'Prop nodes LCC', 'Avg shortest path', 'Modularity', 'Radius', 'Diameter']
network_df[network_df['metric_name'].isin(x_to_keep) & network_df.save_name.str.contains('gpt-3.5')].groupby(['save_name', 'metric_name'])['_metric_value'].agg(['count', 'mean', 'sem']).round(3)
# Out:
# Empty DataFrame
# Columns: [count, mean, sem]
# Index: []

# %%
# non-GPT 3.5 
network_df[network_df['metric_name'].isin(x_to_keep) & ~network_df.save_name.str.contains('gpt-3.5')].groupby(['save_name', 'metric_name'])['_metric_value'].agg(['count', 'mean', 'sem']).round(3)
# Out:
#                                                                         count  \
# save_name                                          metric_name
# global-expressive_gpt-4o-mini_w_interests_w_reason Avg clustering coef     30
#                                                    Avg shortest path       30
#                                                    Density                 30
#                                                    Diameter                30
#                                                    Modularity              30
#                                                    Prop nodes LCC          30
#                                                    Radius                  30
# global-expressive_gpt-4o_w_interests               Avg clustering coef     30
#                                                    Avg shortest path       30
#                                                    Density                 30
#                                                    Diameter                30
#                                                    Modularity              30
#                                                    Prop nodes LCC          30
#                                                    Radius                  30
# global-expressive_gpt-4o_w_interests_w_reason      Avg clustering coef     30
#                                                    Avg shortest path       30
#                                                    Density                 30
#                                                    Diameter                30
#                                                    Modularity              30
#                                                    Prop nodes LCC          30
#                                                    Radius                  30
# global-expressive_gpt-4o_w_names_w_interests_w_... Avg clustering coef     20
#                                                    Avg shortest path       20
#                                                    Density                 20
#                                                    Diameter                20
#                                                    Modularity              20
#                                                    Prop nodes LCC          20
#                                                    Radius                  20
# global_gpt-4o_w_interests                          Avg clustering coef     30
#                                                    Avg shortest path       30
#                                                    Density                 30
#                                                    Diameter                30
#                                                    Modularity              30
#                                                    Prop nodes LCC          30
#                                                    Radius                  30
# real                                               Avg clustering coef      8
#                                                    Avg shortest path        8
#                                                    Density                  8
#                                                    Diameter                 8
#                                                    Modularity               8
#                                                    Prop nodes LCC           8
#                                                    Radius                   8
# sequential_gpt-4o_w_interests                      Avg clustering coef     30
#                                                    Avg shortest path       30
#                                                    Density                 30
#                                                    Diameter                30
#                                                    Modularity              30
#                                                    Prop nodes LCC          30
#                                                    Radius                  30
#
#                                                                          mean  \
# save_name                                          metric_name
# global-expressive_gpt-4o-mini_w_interests_w_reason Avg clustering coef  0.313
#                                                    Avg shortest path    0.680
#                                                    Density              0.100
#                                                    Diameter             1.384
#                                                    Modularity           0.424
#                                                    Prop nodes LCC       0.790
#                                                    Radius               0.809
# global-expressive_gpt-4o_w_interests               Avg clustering coef  0.459
#                                                    Avg shortest path    1.192
#                                                    Density              0.079
#                                                    Diameter             2.685
#                                                    Modularity           0.697
#                                                    Prop nodes LCC       0.736
#                                                    Radius               1.425
# global-expressive_gpt-4o_w_interests_w_reason      Avg clustering coef  0.322
#                                                    Avg shortest path    0.779
#                                                    Density              0.101
#                                                    Diameter             1.515
#                                                    Modularity           0.508
#                                                    Prop nodes LCC       0.697
#                                                    Radius               0.830
# global-expressive_gpt-4o_w_names_w_interests_w_... Avg clustering coef  0.384
#                                                    Avg shortest path    0.541
#                                                    Density              0.211
#                                                    Diameter             1.176
#                                                    Modularity           0.266
#                                                    Prop nodes LCC       0.999
#                                                    Radius               0.716
# global_gpt-4o_w_interests                          Avg clustering coef  0.241
#                                                    Avg shortest path    1.093
#                                                    Density              0.055
#                                                    Diameter             2.344
#                                                    Modularity           0.681
#                                                    Prop nodes LCC       0.515
#                                                    Radius               1.313
# real                                               Avg clustering coef  0.454
#                                                    Avg shortest path    0.635
#                                                    Density              0.197
#                                                    Diameter             1.307
#                                                    Modularity           0.379
#                                                    Prop nodes LCC       0.990
#                                                    Radius               0.840
# sequential_gpt-4o_w_interests                      Avg clustering coef  0.784
#                                                    Avg shortest path    0.749
#                                                    Density              0.274
#                                                    Diameter             1.573
#                                                    Modularity           0.501
#                                                    Prop nodes LCC       0.921
#                                                    Radius               0.886
#
#                                                                           sem
# save_name                                          metric_name
# global-expressive_gpt-4o-mini_w_interests_w_reason Avg clustering coef  0.022
#                                                    Avg shortest path    0.015
#                                                    Density              0.007
#                                                    Diameter             0.045
#                                                    Modularity           0.019
#                                                    Prop nodes LCC       0.024
#                                                    Radius               0.026
# global-expressive_gpt-4o_w_interests               Avg clustering coef  0.016
#                                                    Avg shortest path    0.044
#                                                    Density              0.001
#                                                    Diameter             0.124
#                                                    Modularity           0.006
#                                                    Prop nodes LCC       0.044
#                                                    Radius               0.056
# global-expressive_gpt-4o_w_interests_w_reason      Avg clustering coef  0.036
#                                                    Avg shortest path    0.027
#                                                    Density              0.015
#                                                    Diameter             0.065
#                                                    Modularity           0.015
#                                                    Prop nodes LCC       0.047
#                                                    Radius               0.039
# global-expressive_gpt-4o_w_names_w_interests_w_... Avg clustering coef  0.022
#                                                    Avg shortest path    0.014
#                                                    Density              0.012
#                                                    Diameter             0.039
#                                                    Modularity           0.018
#                                                    Prop nodes LCC       0.001
#                                                    Radius               0.023
# global_gpt-4o_w_interests                          Avg clustering coef  0.030
#                                                    Avg shortest path    0.047
#                                                    Density              0.005
#                                                    Diameter             0.137
#                                                    Modularity           0.021
#                                                    Prop nodes LCC       0.049
#                                                    Radius               0.069
# real                                               Avg clustering coef  0.043
#                                                    Avg shortest path    0.047
#                                                    Density              0.046
#                                                    Diameter             0.122
#                                                    Modularity           0.050
#                                                    Prop nodes LCC       0.010
#                                                    Radius               0.084
# sequential_gpt-4o_w_interests                      Avg clustering coef  0.005
#                                                    Avg shortest path    0.025
#                                                    Density              0.003
#                                                    Diameter             0.057
#                                                    Modularity           0.002
#                                                    Prop nodes LCC       0.031
#                                                    Radius               0.036

# %%
# main results - GPT 3.5 metrics, separate plots
to_keep = ['real', 'global_gpt-3.5-turbo', 'local_gpt-3.5-turbo', 'sequential_gpt-3.5-turbo']
to_keep = ['real', 'global_gpt-4o_w_interests', 'global-expressive_gpt-4o_w_names_w_interests_w_reason', 'sequential_gpt-4o_w_interests']
kept_df = network_df[network_df.save_name.isin(to_keep)]
pastel_palette = sns.color_palette("deep")
colors = {'real': pastel_palette[0],
          'global_gpt-4o_w_interests': pastel_palette[3],
          'global-expressive_gpt-4o_w_interests': pastel_palette[4],
          'global-expressive_gpt-4o_w_interests_w_reason': pastel_palette[5],
          'global-expressive_gpt-4o-mini_w_interests_w_reason': pastel_palette[6],
          'sequential_gpt-4o_w_interests': pastel_palette[7],
          'global-expressive_gpt-4o_w_names_w_interests_w_reason': pastel_palette[8]}
plot_metrics_separately(kept_df, plot_type='default', x_to_keep=x_to_keep, palette=colors, 
                            simplify_legend=True, legend_mapper=None)
# Out:
# Dropping node-level stats: kept 616 out of 13657 rows
# Keeping rows in ['Density', 'Avg clustering coef', 'Prop nodes LCC', 'Avg shortest path', 'Modularity', 'Radius', 'Diameter']: kept 616 out of 616 rows

# %%
# GPT 3.5 - main results on homophily
to_keep = ['global_gpt-3.5-turbo', 'local_gpt-3.5-turbo', 'sequential_gpt-3.5-turbo', 'sequential_gpt-3.5-turbo_ALL_SHUFFLED', 'sequential_gpt-3.5-turbo_w_interests']
to_keep = ['real', 'global_gpt-4o_w_interests', 'global-expressive_gpt-4o_w_names_w_interests_w_reason', 'sequential_gpt-4o_w_interests']
kept_df = homophily_df[homophily_df.save_name.isin(to_keep) & (homophily_df['demo'] != 'age')]
pastel_palette = sns.color_palette("deep")
colors = {'real': pastel_palette[0],
          'global_gpt-4o_w_interests': pastel_palette[3],
          'global-expressive_gpt-4o_w_interests': pastel_palette[4],
          'global-expressive_gpt-4o_w_interests_w_reason': pastel_palette[5],
          'global-expressive_gpt-4o-mini_w_interests_w_reason': pastel_palette[6],
          'sequential_gpt-4o_w_interests': pastel_palette[7],
          'global-expressive_gpt-4o_w_names_w_interests_w_reason': pastel_palette[8]}
make_plot(kept_df, plot_homophily=True, plot_type='default', y_lim=(0.7, 2.2), figsize=(14, 5), dodge=0.65, palette=colors)

# %%
# compare GPT 3.5 vs GPT 4o
to_keep = ['real', 'sequential_gpt-3.5-turbo', 'sequential_gpt-4o', 'sequential_gpt-4o_n5']

to_keep = ['real', 'global_gpt-4o_w_interests', 'global-expressive_gpt-4o_w_names_w_interests_w_reason', 'sequential_gpt-4o_w_interests']
#to_keep = ['real', 'global-expressive_gpt-4o_w_names_w_interests_w_reason', 'sequential_gpt-4o_w_interests']

kept_df = network_df[network_df.save_name.isin(to_keep)]
legend_mapper = {'real': 'Real',
                 'global_gpt-4o_w_interests': 'global_gpt-4o_w_interests',
                 'global-expressive_gpt-4o_w_interests': 'global-expressive_gpt-4o_w_interests',
                 'global-expressive_gpt-4o_w_interests_w_reason': 'global-expressive_gpt-4o_w_interests_w_reason',
                 'global-expressive_gpt-4o-mini_w_interests_w_reason': 'global-expressive_gpt-4o-mini_w_interests_w_reason',
                 'global-expressive_gpt-4o_w_names_w_interests_w_reason': 'global-expressive_gpt-4o_w_names_w_interests_w_reason',
                 'sequential_gpt-4o_w_interests': 'sequential_gpt-4o_w_interests'}
pastel_palette = sns.color_palette("deep")
colors = {'real': pastel_palette[0],
          'global_gpt-4o_w_interests': pastel_palette[3],
          'global-expressive_gpt-4o_w_interests': pastel_palette[4],
          'global-expressive_gpt-4o_w_interests_w_reason': pastel_palette[5],
          'global-expressive_gpt-4o-mini_w_interests_w_reason': pastel_palette[6],
          'sequential_gpt-4o_w_interests': pastel_palette[7],
          'global-expressive_gpt-4o_w_names_w_interests_w_reason': pastel_palette[8]}

plot_metrics_separately(kept_df, plot_type='default', x_to_keep=x_to_keep, palette=colors, 
                            simplify_legend=True, legend_mapper=None)
make_plot(kept_df, plot_type='default', legend_mapper=legend_mapper, palette=colors, x_to_keep=x_to_keep, figsize=(11, 4), legend_pos=(1,1))

to_keep.remove('real')
kept_df = homophily_df[homophily_df.save_name.isin(to_keep) & (homophily_df['demo'] != 'age')]
make_plot(kept_df, plot_homophily=True, plot_type='default', legend_mapper=legend_mapper, palette=colors, 
          dodge=0.55, figsize=(11, 5), legend_pos=(1,1))
# Out:
# Dropping node-level stats: kept 616 out of 13657 rows
# Keeping rows in ['Density', 'Avg clustering coef', 'Prop nodes LCC', 'Avg shortest path', 'Modularity', 'Radius', 'Diameter']: kept 616 out of 616 rows
# Dropping node-level stats: kept 616 out of 13657 rows
# Keeping rows in ['Density', 'Avg clustering coef', 'Prop nodes LCC', 'Avg shortest path', 'Modularity', 'Radius', 'Diameter']: kept 616 out of 616 rows

# %%
# compare GPT 3.5 vs Llama
to_keep = ['real', 'sequential_gpt-3.5-turbo', 'sequential_llama3.1-8b', 'sequential_llama3.1-8b_n5', 'sequential_llama3.1-70b', 'sequential_llama3.1-70b_n5']
to_keep = ['real', 'global_gpt-4o_w_interests', 'global-expressive_gpt-4o_w_interests', 'global-expressive_gpt-4o_w_interests_w_reason', 'global-expressive_gpt-4o-mini_w_interests_w_reason',  'sequential_gpt-4o_w_interests']
kept_df = network_df[network_df.save_name.isin(to_keep)]
legend_mapper = {'real': 'Real',
                 'global_gpt-4o_w_interests': 'global_gpt-4o_w_interests',
                 'global-expressive_gpt-4o_w_interests': 'global-expressive_gpt-4o_w_interests',
                 'global-expressive_gpt-4o_w_interests_w_reason': 'global-expressive_gpt-4o_w_interests_w_reason',
                 'global-expressive_gpt-4o-mini_w_interests_w_reason': 'global-expressive_gpt-4o-mini_w_interests_w_reason',
                 'sequential_gpt-4o_w_interests': 'sequential_gpt-4o_w_interests'}
pastel_palette = sns.color_palette("pastel")
colors = {'real': pastel_palette[0],
          'global_gpt-4o_w_interests': pastel_palette[3],
          'global-expressive_gpt-4o_w_interests': pastel_palette[4],
          'global-expressive_gpt-4o_w_interests_w_reason': pastel_palette[5],
          'sequential_gpt-4o_w_interests': pastel_palette[6]}

make_plot(kept_df, plot_homophily=False, plot_type='default', legend_mapper=legend_mapper, palette=colors,
          x_to_keep=x_to_keep, figsize=(11, 4), legend_pos=(1,1), dodge=0.67)

to_keep.remove('real')
kept_df = homophily_df[homophily_df.save_name.isin(to_keep) & (homophily_df['demo'] != 'age')]
make_plot(kept_df, plot_homophily=True, plot_type='default', legend_mapper=legend_mapper, palette=colors, 
          dodge=0.65, figsize=(11, 5), legend_pos=(1,1))
# Out:
# Dropping node-level stats: kept 1106 out of 24647 rows
# Keeping rows in ['Density', 'Avg clustering coef', 'Prop nodes LCC', 'Avg shortest path', 'Modularity']: kept 790 out of 1106 rows
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 18
#      11 pastel_palette = sns.color_palette("pastel")
#      12 colors = {'real': pastel_palette[0],
#      13           'global_gpt-4o_w_interests': pastel_palette[3],
#      14           'global-expressive_gpt-4o_w_interests': pastel_palette[4],
#      15           'global-expressive_gpt-4o_w_interests_w_reason': pastel_palette[5],
#      16           'sequential_gpt-4o_w_interests': pastel_palette[6]}
# ---> 18 make_plot(kept_df, plot_homophily=False, plot_type='default', legend_mapper=legend_mapper, palette=colors,
#      19           x_to_keep=x_to_keep, figsize=(11, 4), legend_pos=(1,1), dodge=0.67)
#      21 to_keep.remove('real')
#      22 kept_df = homophily_df[homophily_df.save_name.isin(to_keep) & (homophily_df['demo'] != 'age')]
#
# File ~/Git/llm-network/plotting.py:194, in make_plot(network_metrics_df, save_name, plot_type, plot_homophily, homophily_metric, x_to_keep, figsize, y_lim, simplify_legend, legend_mapper, legend_pos, palette, dodge)
#     192 # default is SE + data points
#     193 if plot_type == 'default':
# --> 194     sns.stripplot(data=network_metrics_df, x=x_name, y='_metric_value',
#     195                   hue='save_name', palette=palette, dodge=dodge, alpha=0.8, legend=True, zorder=1)
#     196     sns.pointplot(data=network_metrics_df, x=x_name, y='_metric_value', errorbar='se',
#     197                   hue='save_name', palette='dark:black', dodge=dodge, legend=False,
#     198                   capsize=0.05, linestyle='none', zorder=2)  # use zorder to determine which plot ends up on top
#     199 else:
#
# File /opt/homebrew/lib/python3.11/site-packages/seaborn/categorical.py:2106, in stripplot(data, x, y, hue, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2103 hue_order = p._palette_without_hue_backcompat(palette, hue_order)
#    2104 palette, hue_order = p._hue_backcompat(color, palette, hue_order)
# -> 2106 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    2107 color = _default_color(ax.scatter, hue, color, kwargs)
#    2108 edgecolor = p._complement_color(edgecolor, color, p._hue_map)
#
# File /opt/homebrew/lib/python3.11/site-packages/seaborn/_base.py:838, in VectorPlotter.map_hue(self, palette, order, norm, saturation)
#     837 def map_hue(self, palette=None, order=None, norm=None, saturation=1):
# --> 838     mapping = HueMapping(self, palette, order, norm, saturation)
#     839     self._hue_map = mapping
#
# File /opt/homebrew/lib/python3.11/site-packages/seaborn/_base.py:150, in HueMapping.__init__(self, plotter, palette, order, norm, saturation)
#     147 elif map_type == "categorical":
#     149     cmap = norm = None
# --> 150     levels, lookup_table = self.categorical_mapping(
#     151         data, palette, order,
#     152     )
#     154 # --- Option 3: datetime mapping
#     155
#     156 else:
#     157     # TODO this needs actual implementation
#     158     cmap = norm = None
#
# File /opt/homebrew/lib/python3.11/site-packages/seaborn/_base.py:234, in HueMapping.categorical_mapping(self, data, palette, order)
#     232     if any(missing):
#     233         err = "The palette dictionary is missing keys: {}"
# --> 234         raise ValueError(err.format(missing))
#     236     lookup_table = palette
#     238 else:
#
# ValueError: The palette dictionary is missing keys: {'global-expressive_gpt-4o-mini_w_interests_w_reason'}

# %%
# compare GPT 3.5 vs Gemma
to_keep = ['real', 'global_gpt-4o_w_interests', 'global-expressive_gpt-4o_w_interests', 'global-expressive_gpt-4o_w_interests_w_reason', 'sequential_gpt-4o_w_interests']
kept_df = network_df[network_df.save_name.isin(to_keep)]
legend_mapper = {'real': 'Real',
                 'global_gpt-4o_w_interests': 'global_gpt-4o_w_interests',
                 'global-expressive_gpt-4o_w_interests': 'global-expressive_gpt-4o_w_interests',
                 'global-expressive_gpt-4o_w_interests_w_reason': 'global-expressive_gpt-4o_w_interests_w_reason',
                 'sequential_gpt-4o_w_interests': 'sequential_gpt-4o_w_interests'}
pastel_palette = sns.color_palette("pastel")
colors = {'real': pastel_palette[0],
          'global_gpt-4o_w_interests': pastel_palette[3],
          'global-expressive_gpt-4o_w_interests': pastel_palette[4],
          'global-expressive_gpt-4o_w_interests_w_reason': pastel_palette[5],
          'sequential_gpt-4o_w_interests': pastel_palette[6]}
make_plot(kept_df, plot_homophily=False, plot_type='default', legend_mapper=legend_mapper, palette=colors,
          x_to_keep=x_to_keep, figsize=(11, 4), legend_pos=(1,1), dodge=0.65) # , y_lim=(-0.1, 1.9))

to_keep.remove('real')
kept_df = homophily_df[homophily_df.save_name.isin(to_keep) & (homophily_df['demo'] != 'age')]
make_plot(kept_df, plot_homophily=True, plot_type='default', legend_mapper=legend_mapper, palette=colors,
          figsize=(11, 5), dodge=0.6, legend_pos=(1,1))
# Out:
# Dropping node-level stats: kept 896 out of 19937 rows
# Keeping rows in ['Density', 'Avg clustering coef', 'Prop nodes LCC', 'Avg shortest path', 'Modularity']: kept 512 out of 896 rows

# %%
# homophily with interests
to_keep = ['real', 'global_gpt-4o_w_interests', 'global-expressive_gpt-4o_w_interests', 'global-expressive_gpt-4o_w_interests_w_reason', 'sequential_gpt-4o_w_interests']
kept_df = network_df[network_df.save_name.isin(to_keep)]
legend_mapper = {'real': 'Real',
                 'global_gpt-4o_w_interests': 'global_gpt-4o_w_interests',
                 'global-expressive_gpt-4o_w_interests': 'global-expressive_gpt-4o_w_interests',
                 'global-expressive_gpt-4o_w_interests_w_reason': 'global-expressive_gpt-4o_w_interests_w_reason',
                 'sequential_gpt-4o_w_interests': 'sequential_gpt-4o_w_interests'}
pastel_palette = sns.color_palette("pastel")
colors = {'real': pastel_palette[0],
          'global_gpt-4o_w_interests': pastel_palette[3],
          'global-expressive_gpt-4o_w_interests': pastel_palette[4],
          'global-expressive_gpt-4o_w_interests_w_reason': pastel_palette[5],
          'sequential_gpt-4o_w_interests': pastel_palette[6]}
kept_df = homophily_df[homophily_df.save_name.isin(to_keep) & (homophily_df['demo'] != 'age')]
make_plot(kept_df, plot_homophily=True, plot_type='default', legend_mapper=legend_mapper, palette=colors,
          figsize=(11, 5), dodge=0.53)

# %%
# compare across temperatures

to_keep = ['real', 'global_gpt-4o_w_interests', 'global-expressive_gpt-4o_w_interests', 'global-expressive_gpt-4o_w_interests_w_reason', 'sequential_gpt-4o_w_interests']
kept_df = network_df[network_df.save_name.isin(to_keep)]
legend_mapper = {'real': 'Real',
                 'global_gpt-4o_w_interests': 'global_gpt-4o_w_interests',
                 'global-expressive_gpt-4o_w_interests': 'global-expressive_gpt-4o_w_interests',
                 'global-expressive_gpt-4o_w_interests_w_reason': 'global-expressive_gpt-4o_w_interests_w_reason',
                 'sequential_gpt-4o_w_interests': 'sequential_gpt-4o_w_interests'}
pastel_palette = sns.color_palette("pastel")
colors = {'real': pastel_palette[0],
          'global_gpt-4o_w_interests': pastel_palette[3],
          'global-expressive_gpt-4o_w_interests': pastel_palette[4],
          'global-expressive_gpt-4o_w_interests_w_reason': pastel_palette[5],
          'sequential_gpt-4o_w_interests': pastel_palette[6]}
kept_df = network_df[network_df.save_name.isin(to_keep)]
make_plot(kept_df, plot_homophily=False, plot_type='default', legend_mapper=legend_mapper, palette=colors,
          x_to_keep=x_to_keep, figsize=(11, 4), legend_pos=(1.252,1))

# compare different temperatures
to_keep.remove('real')
kept_df = homophily_df[homophily_df.save_name.isin(to_keep) & (homophily_df['demo'] != 'age')]
make_plot(kept_df, plot_homophily=True, plot_type='default', legend_mapper=legend_mapper, palette=colors,
          figsize=(11, 5), legend_pos=(1,1), dodge=0.53)
# Out:
# Dropping node-level stats: kept 896 out of 19937 rows
# Keeping rows in ['Density', 'Avg clustering coef', 'Prop nodes LCC', 'Avg shortest path', 'Modularity']: kept 512 out of 896 rows

# %%
# testing "Pay all to all demographics"
to_keep = ['real', 'sequential_gpt-3.5-turbo', 'sequential_gpt-3.5-turbo_prompt_all', 'sequential_gpt-4o', 'sequential_gpt-4o_prompt_all', 'sequential_gpt-3.5-turbo_w_reason']
kept_df = network_df[network_df.save_name.isin(to_keep)]
legend_mapper = {'real': 'Real', 
                 'sequential_gpt-3.5-turbo': 'Seq. (GPT-3.5)',
                 'sequential_gpt-3.5-turbo_prompt_all': 'Seq.+"all" (GPT-3.5)',
                 'sequential_gpt-4o': 'Seq. (GPT-4o)',
                 'sequential_gpt-4o_prompt_all': 'Seq.+"all" (GPT-4o)',
                 'sequential_gpt-3.5-turbo_w_reason': 'Seq.+"reason" (GPT-3.5)'}
colors = {'real': pastel_palette[0],
                 'sequential_gpt-3.5-turbo': pastel_palette[3],
                 'sequential_gpt-3.5-turbo_prompt_all': pastel_palette[4],
                 'sequential_gpt-4o': pastel_palette[5],
                 'sequential_gpt-4o_prompt_all': pastel_palette[6],
                 'sequential_gpt-3.5-turbo_w_reason': pastel_palette[7]}
make_plot(kept_df, plot_homophily=False, plot_type='default', legend_mapper=legend_mapper, palette=colors,
          x_to_keep=x_to_keep, figsize=(11, 4), dodge=0.65)

to_keep.remove('real')
kept_df = homophily_df[homophily_df.save_name.isin(to_keep) & (homophily_df['demo'] != 'age')]
make_plot(kept_df, plot_homophily=True, plot_type='default', figsize=(11, 5), legend_mapper=legend_mapper, palette=colors,
          dodge=0.62, legend_pos=(1,1))
# Out:
# Dropping node-level stats: kept 686 out of 15227 rows
# Keeping rows in ['Density', 'Avg clustering coef', 'Prop nodes LCC', 'Avg shortest path', 'Modularity']: kept 490 out of 686 rows

# %%
to_keep = ['real', 'global_gpt-3.5-turbo', 'local_gpt-3.5-turbo', 'sequential_gpt-3.5-turbo']
kept_df = network_df[network_df.save_name.isin(to_keep)]

palette = get_pallete(kept_df)
fig, axes = plt.subplots(2, 2, figsize=(8, 6))
fig.subplots_adjust(hspace=0.3)
bins = np.arange(0, 1.01, 0.05)
print(bins)

for i, ax in enumerate(axes.flatten()):
    name = to_keep[i]
    degrees = kept_df[(kept_df.save_name == name) & (kept_df.metric_name == 'Degree centrality')]['_metric_value'].values
    print(name, len(degrees), degrees.max())
    ax.hist(degrees, bins=bins, color=palette[name])
    ax.set_yscale('log')
    if i % 2 == 0:
        ax.set_ylabel('Num nodes (log)', fontsize=14)
    if i >= 2:
        ax.set_xlabel('Degree', fontsize=14)
    ax.set_title(get_short_name(name), fontsize=16)
    ax.grid(alpha=0.2)
# Out:
# [0.   0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65
#  0.7  0.75 0.8  0.85 0.9  0.95 1.  ]
# real 347 0.7666666666666666
# global_gpt-3.5-turbo 1500 1.0
# local_gpt-3.5-turbo 1500 0.5306122448979591
# sequential_gpt-3.5-turbo 1500 0.6938775510204082

# %%
real_df = load_real_homophily(same_group=True)
real_df.sort_values('save_name').round(2)
# Out:
#               save_name                   demo  _metric_value
# 4              gss-1985                 gender           1.19
# 2              gss-1985         race/ethnicity           1.32
# 3              gss-1985               religion           1.63
# 7              gss-2004                 gender           1.12
# 5              gss-2004         race/ethnicity           1.47
# 6              gss-2004               religion           2.08
# 0        laniado-friend                 gender           1.04
# 1   laniado-interaction                 gender           1.12
# 10              myspace                 gender           0.96
# 8               myspace         race/ethnicity           1.96
# 9               myspace               religion           1.69
# 11              twitter  political affiliation           1.40

# %%
# age homophily
fn = os.path.join(PATH_TO_TEXT_FILES, 'us_50_gpt4o_w_interests.json')
with open(fn) as f:
    personas = json.load(f)

method = 'sequential'
model = 'gpt-3.5-turbo'
list_of_G = load_list_of_graphs(f'{method}_{model}', 0, 30, directed=False)
plot_expected_vs_observed_age_gaps(list_of_G, personas)

# %%
def report_isolation_index(method, model):
    list_of_G = load_list_of_graphs(f'{method}_{model}', 0, 30, directed=False)
    print(f'{method}_{model}: found {len(list_of_G)} graphs')
    isolation = []
    exposure_c = []
    exposure_l = []
    for G in list_of_G:
        i, c, l = compute_isolation_index(G, personas)
        isolation.append(i)
        exposure_c.append(c)
        exposure_l.append(l)
    print(f'Isolation: {np.mean(isolation):0.3f}, {np.std(isolation)/np.sqrt(len(isolation)):0.3f}')
    print(f'Avg exposure, conservative: {np.mean(exposure_c):0.3f}, {np.std(exposure_c)/np.sqrt(len(exposure_c)):0.3f}')
    print(f'Avg exposure, liberal: {np.mean(exposure_l):0.3f}, {np.std(exposure_l)/np.sqrt(len(exposure_l)):0.3f}')

model = 'gpt-3.5-turbo'
for method in ['global', 'local', 'sequential']:
    print(method)
    report_isolation_index(method, model)
    print()
# Out:
# global
# global_gpt-3.5-turbo: found 30 graphs
# Isolation: nan, nan
# Avg exposure, conservative: nan, nan
# Avg exposure, liberal: nan, nan
#
# local
# local_gpt-3.5-turbo: found 30 graphs
# Isolation: 0.729, 0.020
# Avg exposure, conservative: 0.854, 0.012
# Avg exposure, liberal: 0.126, 0.008
#
# sequential
# sequential_gpt-3.5-turbo: found 30 graphs
# Isolation: 0.530, 0.027
# Avg exposure, conservative: 0.763, 0.016
# Avg exposure, liberal: 0.233, 0.013
# /Users/serinachang/Documents/research/llm_social_network/git_src_public/analyze_networks.py:280: RuntimeWarning: invalid value encountered in divide
#   share_conservative = num_neighbors_c / (num_neighbors_c + num_neighbors_l)

# %%
def report_polarization(method, model):
    list_of_G = load_list_of_graphs(f'{method}_{model}', 0, 30, directed=False)
    print(f'{method}_{model}: found {len(list_of_G)} graphs')
    pol = []
    for G in list_of_G:
        p = compute_polarization(G, personas)
        pol.append(p)
    print(f'Polarization: mean={np.mean(pol):0.3f}, se={np.std(pol)/np.sqrt(len(pol)):0.3f}')

model = 'gpt-3.5-turbo'
for method in ['global', 'local', 'sequential']:
    print(method)
    report_polarization(method, model)
    print()
# Out:
# global
# global_gpt-3.5-turbo: found 30 graphs
# Polarization: mean=0.332, se=0.032
#
# local
# local_gpt-3.5-turbo: found 30 graphs
# Polarization: mean=0.639, se=0.037
#
# sequential
# sequential_gpt-3.5-turbo: found 30 graphs
# Polarization: mean=0.515, se=0.041

# %% [markdown]
# # Comparison to classical models

# %%
metrics = ['Density', 'Avg clustering coef', 'Prop nodes LCC', 'Avg shortest path', 'Modularity', 'Degree centrality']
real_mean = network_df[network_df['save_name'] == 'real'].groupby('metric_name')['_metric_value'].agg(['mean', 'sem'])
real_mean
# Out:
#                             mean       sem
# metric_name
# Avg clustering coef     0.454084  0.042551
# Avg shortest path       0.635332  0.047373
# Betweenness centrality  0.032375  0.002592
# Closeness centrality    0.428230  0.006916
# Degree centrality       0.175672  0.008144
# Density                 0.197454  0.046188
# Diameter                1.307066  0.121943
# Modularity              0.378153  0.049146
# Prop nodes LCC          0.989583  0.010417
# Radius                  0.839506  0.084416

# %%
n = 50
total_edges = n * (n-1) / 2
real_density = real_mean.loc['Density']['mean'] # real networks' mean density
exp_edges = total_edges * real_density
print(exp_edges)
# Out:
# 241.8815914855653

# %%
# erdos-renyi
p = real_density
edges = []
for s in range(30):
    G = nx.erdos_renyi_graph(n, p, seed=s)
    edges.append(len(G.edges()))
    fn = os.path.join(PATH_TO_TEXT_FILES, f'er_{s}.adj')
    nx.write_adjlist(G, fn)
plt.hist(edges, bins=20)
plt.show()

# %%
# barabasi-albert
n = 50
best_m = None 
best_diff = 1e6
for m in range(1, 8):
    G = nx.barabasi_albert_graph(n, m, seed=s)
    num_edges = len(G.edges())
    diff = np.abs(len(G.edges()) - exp_edges)
    if diff < best_diff:
        best_diff = diff 
        best_m = m 
print('Using m =', best_m)

edges = []
for s in range(30):
    G = nx.barabasi_albert_graph(n, best_m, seed=s)
    edges.append(len(G.edges()))
    fn = os.path.join(PATH_TO_TEXT_FILES, f'ba_{s}.adj')
    nx.write_adjlist(G, fn)
print(set(edges))
plt.hist(edges, bins=20)
plt.show()
# Out:
# Using m = 5
# {225}

# %%
# watts-strogatz 
for k in np.arange(4, 16, 2):
    for p in np.arange(0.05, 0.16, 0.05):
        for s in range(5):
            G = nx.watts_strogatz_graph(n, k, p, seed=s)
            assert len(G.edges()) == (n*k)/2

# %%
# fit k (number of neighbors)
best_k = None 
best_diff = 1e6
p = 0.01
for k in np.arange(8, 13, 2):
    G = nx.watts_strogatz_graph(n, k, p, seed=s)
    num_edges = len(G.edges())
    assert num_edges == (n*k)/2
    diff = np.abs(num_edges - exp_edges)
    print(k, diff)
    if diff < best_diff:
        best_diff = diff 
        best_k = k 
print('Using k =', best_k)
# Out:
# 8 41.88159148556531
# 10 8.118408514434691
# 12 58.11840851443469
# Using k = 10

# %%
# fit p (rewiring probability)
best_p = None 
best_diff = 1e6
p_options = np.arange(0.01, 0.5, 0.01)
p_clustering = []
for p in p_options:
    clustering = []
    for s in range(30):
        G = nx.watts_strogatz_graph(n, best_k, p)
        clustering.append(nx.average_clustering(G))
    p_clustering.append(np.mean(clustering))
plt.figure(figsize=(6,4))
plt.plot(p_options, p_clustering)
diff = np.abs(p_clustering - real_mean.loc['Avg clustering coef']['mean'])
plt.plot(p_options, diff)
min_val = p_options[np.argmin(diff)]
best_p = min_val.round(3)
print('best p = ', best_p)
ymin, ymax = plt.ylim()
plt.vlines([min_val], ymin, ymax, color='grey')
plt.show()
# Out:
# best p =  0.15

# %%
for s in range(30):
    G = nx.watts_strogatz_graph(n, best_k, best_p, seed=s)
    fn = os.path.join(PATH_TO_TEXT_FILES, f'ws_{s}.adj')
    nx.write_adjlist(G, fn)

# %%
# summarize network models
min_seed = 0
max_seed = 29
for model in ['er', 'ba', 'ws']: 
    list_of_G, t1, t2 = load_list_of_graphs(model, min_seed, max_seed+1, directed=False, include_ts=True)
    print(f'{model}: found {len(list_of_G)} graphs ({t1} TO {t2})')
    summarize_network_metrics(list_of_G, None, None, model, demos=False)
    print()
# Out:
# er: found 30 graphs (Mon Aug 26 15:10:24 2024 TO Mon Aug 26 15:10:24 2024)
# Saved network metrics to er/network_metrics.csv
#
# ba: found 30 graphs (Mon Aug 26 15:23:15 2024 TO Mon Aug 26 15:23:15 2024)
# Saved network metrics to ba/network_metrics.csv
#
# ws: found 30 graphs (Mon Aug 26 15:35:46 2024 TO Mon Aug 26 15:35:46 2024)
# Saved network metrics to ws/network_metrics.csv

# %%
network_df = pd.read_csv(f'stats/real/network_metrics.csv')
metric_dfs = [network_df]
homophily_dfs = []

# load network metrics and homophily for generated networks
model = 'gpt-3.5-turbo'
for method in ['global', 'local', 'sequential']: # , 'iterative']:
    metric_dfs.append(pd.read_csv(f'stats/{method}_{model}/network_metrics.csv'))

for model in ['er', 'ba', 'ws']:
    metric_dfs.append(pd.read_csv(f'stats/{model}/network_metrics.csv'))

network_df = pd.concat(metric_dfs)
print(network_df.groupby('save_name').size())
# Out:
# save_name
# ba                          4710
# er                          4710
# global_gpt-3.5-turbo        4710
# local_gpt-3.5-turbo         4710
# real                        1097
# sequential_gpt-3.5-turbo    4710
# ws                          4710
# dtype: int64

# %%
results = []
for method in ['er', 'ba', 'ws', 'global', 'local', 'sequential']:
    if len(method) > 2:
        save_name = f'{method}_gpt-3.5-turbo'
    else:
        save_name = method
    for metric in ['density', 'avg_clustering_coef', 'prop_nodes_lcc', 'avg_shortest_path', 'modularity', 'degree_centrality']:
        mean_diff, mean_diff_norm, ks_stat, ks_pval = compare_network_metrics(network_df, metric, save_name)
        results.append({'method': method, 'metric': metric, 'mean_diff': mean_diff, 'mean_diff_norm': mean_diff_norm,
                        'ks_stat': ks_stat, 'ks_pval': ks_pval})
df = pd.DataFrame(results)
df.round(3)
# Out:
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 347 real and 1500 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 347 real and 1500 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 347 real and 1500 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 347 real and 1500 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 347 real and 1500 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 8 real and 30 generated values
# Found 347 real and 1500 generated values
#         method               metric  mean_diff  mean_diff_norm  ks_stat  \
# 0           er              density      0.002           0.013    0.625
# 1           er  avg_clustering_coef      0.257           2.286    1.000
# 2           er       prop_nodes_lcc      0.010           0.378    0.125
# 3           er    avg_shortest_path      0.145           1.156    0.750
# 4           er           modularity      0.149           1.149    0.750
# 5           er    degree_centrality      0.023           0.154    0.465
# 6           ba              density      0.014           0.113    0.625
# 7           ba  avg_clustering_coef      0.153           1.363    0.750
# 8           ba       prop_nodes_lcc      0.010           0.378    0.125
# 9           ba    avg_shortest_path      0.135           1.081    0.750
# 10          ba           modularity      0.151           1.160    0.750
# 11          ba    degree_centrality      0.008           0.053    0.416
# 12          ws              density      0.007           0.054    0.625
# 13          ws  avg_clustering_coef      0.005           0.041    0.375
# 14          ws       prop_nodes_lcc      0.010           0.378    0.125
# 15          ws    avg_shortest_path      0.101           0.808    0.750
# 16          ws           modularity      0.052           0.404    0.500
# 17          ws    degree_centrality      0.028           0.188    0.617
# 18      global              density      0.160           1.311    0.967
# 19      global  avg_clustering_coef      0.383           3.399    0.933
# 20      global       prop_nodes_lcc      0.489          17.740    0.833
# 21      global    avg_shortest_path      0.821           6.547    0.900
# 22      global           modularity      0.385           2.959    0.967
# 23      global    degree_centrality      0.138           0.914    0.740
# 24       local              density      0.025           0.207    0.525
# 25       local  avg_clustering_coef      0.001           0.012    0.250
# 26       local       prop_nodes_lcc      0.010           0.378    0.125
# 27       local    avg_shortest_path      0.048           0.383    0.500
# 28       local           modularity      0.041           0.316    0.500
# 29       local    degree_centrality      0.004           0.023    0.265
# 30  sequential              density      0.048           0.394    0.375
# 31  sequential  avg_clustering_coef      0.041           0.363    0.325
# 32  sequential       prop_nodes_lcc      0.010           0.378    0.125
# 33  sequential    avg_shortest_path      0.075           0.596    0.625
# 34  sequential           modularity      0.011           0.088    0.342
# 35  sequential    degree_centrality      0.026           0.174    0.190
#
#     ks_pval
# 0     0.007
# 1     0.000
# 2     1.000
# 3     0.000
# 4     0.000
# 5     0.000
# 6     0.007
# 7     0.000
# 8     1.000
# 9     0.000
# 10    0.000
# 11    0.000
# 12    0.007
# 13    0.263
# 14    1.000
# 15    0.000
# 16    0.058
# 17    0.000
# 18    0.000
# 19    0.000
# 20    0.000
# 21    0.000
# 22    0.000
# 23    0.000
# 24    0.039
# 25    0.733
# 26    1.000
# 27    0.058
# 28    0.058
# 29    0.000
# 30    0.263
# 31    0.427
# 32    1.000
# 33    0.007
# 34    0.367
# 35    0.000
